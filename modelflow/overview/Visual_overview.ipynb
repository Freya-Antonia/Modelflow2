# %% [markdown]
# # Overview of source code
#
#
# In this notebook, I illustrate the dependencies within the ModelFlow library.

# %%
import graphviz

# %%
dot = graphviz.Digraph('Source code', comment='An overview')

# %% [markdown]
# ## Nodes

# %%
dot.node('A', 'Modelclass')  

dot.node('B', 'Modelpattern')

dot.node('C', 'modeluserfunk')

# %% [markdown]
# ## Edges

# %%
dot.edges(['AB', 'AC'])

# %%
dot
